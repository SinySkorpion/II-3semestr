# %% [markdown]
# <a href="https://colab.research.google.com/github/JoskyPon/AI-and-ML/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Выполнение работы

# %% [markdown]
# #ОТЧЕТ ПО ЛАБОРАТОРНОЙ РАБОТЕ № 1 ПО ДИСЦИПЛИНЫ «Искусственный интеллект и машинное обучение»
#
#
# ##ТЕМА : Машинное обучение: общие сведения и понятия
#
#
# Выполнил: Ивванов Даниил Евгеньевич.
#
# Группа: ПИН-б-о-22-1
#
#
# ##Цель работы
#
#
# Ответить на контрольные вопросы:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.	Дискретные величины нельзя измерить, но их можно посчитать, например, количество людей в очереди или количество машин во дворе. Непрерывные величины, наоборот, нельзя точно подсчитать, но их можно измерить, например, длину и ширину комнаты или скорость автомобиля.
# 2.	В обучении с учителем используется обучающий набор данных, где каждому экземпляру данных соответствует пара "входные данные - ожидаемый ответ". Задачей является поиск модели или алгоритма, который может предсказывать ожидаемые целевые ответы. В обучении без учителя, наоборот, у нас есть только данные, и задачей является поиск закономерностей или структур в этих данных без заранее известных целевых ответов.
# 3.	Если множество возможных ответов конечно, то для решения задачи следует использовать классификацию. Её задача сводится к построению разделяющей кривой, которая позволяет классифицировать каждый экземпляр данных. Если же множество возможных ответов бесконечно, то для решения задачи следует использовать регрессию. Задача регрессии состоит в построении кривой, которая проходит через все тренировочные данные и позволяет предсказывать численные значения.
# 4.	Классификации
# 5.	Проверка модели на валидационных данных важна в машинном обучении по нескольким причинам. Во-первых, она позволяет оценить обобщающую способность модели, то есть ее способность делать точные прогнозы для новых данных. Во-вторых, использование валидационных данных помогает предотвратить переобучение модели, которое может возникнуть при использовании всех тренировочных данных. Наконец, проверка различных моделей на валидационных данных позволяет выбрать наилучшую модель, которая демонстрирует наилучшую производительность на новых данных.модели.
# 6.	Возможные матрицы - это А*В, С*А, так как число столбцов 1-ой матрицы
# = числу строк 2-ой.
# 7. Градиент функции  вычисляется как вектор частных производных:
# ![image.png](data:image/png;base64,...)
# 8. ![image.png](data:image/png;base64,...)
# 9. ![image.png](data:image/png;base64,...)
